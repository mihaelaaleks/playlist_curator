# %%
import pandas as pd
import json
from pathlib import Path

# %%
cwd = Path.cwd()
data_path = cwd.parent / Path('data/my_playlists.json')
f = open(data_path)
playlist_data = json.load(f)
f.close()

# %%
playlists = []
for _, item in enumerate(playlist_data['items']): 
    playlists.append(item)

# %%
cwd = Path.cwd()
cleaned_data_path = cwd.parent / Path('data/my_cleaned_playlists.json')

with open(cleaned_data_path, 'w') as fp: 
    json.dump(playlists, fp)

# %%
df = pd.DataFrame.from_records(playlists)

df
# Out:
#     collaborative                                        description  \
# 0           False
# 1           False                                      aka Work Jams
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False                                  Panic girlie shit
# 8           False
# 9           False  I&#x27;m way too stressed for this shit. Playl...
# 10          False
# 11          False                                art credit: jyundee
# 12          False
# 13          False
# 14          False                               Top era girlie shit
# 15          False
# 16          False                When you hit that combo just right
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/playlist...
# 1   {'spotify': 'https://open.spotify.com/playlist...
# ...

# %%
df.to_pickle('./data/my_cleaned_playlist.pkl')

# %%
unpickled_df = pd.read_pickle('./data/my_cleaned_playlist.pkl')

# %%
unpickled_df

# %%
playlist_items = dict(zip(unpickled_df.id, unpickled_df.name))

# %%
playlist_items
